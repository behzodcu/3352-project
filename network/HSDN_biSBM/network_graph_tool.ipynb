# %%
from graph_tool.all import *

# %%
HSDN_edgelist = []
with open('HSDN.edgelist') as f:
    for line in f:
        HSDN_edgelist.append(line[:-1].split('\t'))
f.close()

# %%
G = Graph()
G.add_edge_list(HSDN_edgelist, hashed = True)
state = minimize_blockmodel_dl(G)
state.draw()
# Out:
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x1ab6516f0, at 0x1ab651b40>

# %%
is_bipartite(G)
# Out:
# True
