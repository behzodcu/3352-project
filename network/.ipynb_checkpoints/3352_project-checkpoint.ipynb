# %%
# !bipartiteSBM/scripts/compile_engines.sh
# Out:
# bipartiteSBM/scripts/compile_engines.sh: line 3: cd: engines/bipartiteSBM-MCMC/: No such file or directory
# bipartiteSBM/scripts/compile_engines.sh: line 4: cd: engines/bipartiteSBM-KL/: No such file or directory

# %%
# !python3 -m pip install -r bipartiteSBM/requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy>=1.17.3 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from -r bipartiteSBM/requirements.txt (line 7)) (1.21.5)
# Requirement already satisfied: numba>=0.46.0 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from -r bipartiteSBM/requirements.txt (line 10)) (0.55.1)
# Requirement already satisfied: loky>=2.6.0 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from -r bipartiteSBM/requirements.txt (line 13)) (3.1.0)
# Requirement already satisfied: jupyterlab>=0.35.4 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from -r bipartiteSBM/requirements.txt (line 16)) (3.3.2)
# Requirement already satisfied: matplotlib>=3.1.1 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from -r bipartiteSBM/requirements.txt (line 19)) (3.5.1)
# Requirement already satisfied: scipy>=1.3.1 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from -r bipartiteSBM/requirements.txt (line 22)) (1.8.0)
# Requirement already satisfied: configparser>=4.0.2 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from -r bipartiteSBM/requirements.txt (line 25)) (5.2.0)
# Requirement already satisfied: clusim>=0.3.1 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from -r bipartiteSBM/requirements.txt (line 28)) (0.4)
# Requirement already satisfied: scikit-learn>=0.20.3 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from -r bipartiteSBM/requirements.txt (line 31)) (1.0.2)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from numba>=0.46.0->-r bipartiteSBM/requirements.txt (line 10)) (41.2.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from numba>=0.46.0->-r bipartiteSBM/requirements.txt (line 10)) (0.38.0)
# Requirement already satisfied: cloudpickle in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from loky>=2.6.0->-r bipartiteSBM/requirements.txt (line 13)) (2.0.0)
# Requirement already satisfied: packaging in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (21.3)
# Requirement already satisfied: jupyter-server~=1.4 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (1.15.6)
# Requirement already satisfied: tornado>=6.1.0 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (6.1)
# Requirement already satisfied: jinja2>=2.1 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (3.1.1)
# Requirement already satisfied: jupyterlab-server~=2.10 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (2.12.0)
# Requirement already satisfied: jupyter-core in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (4.9.2)
# Requirement already satisfied: nbclassic~=0.2 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (0.3.7)
# Requirement already satisfied: ipython in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (8.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from matplotlib>=3.1.1->-r bipartiteSBM/requirements.txt (line 19)) (4.29.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from matplotlib>=3.1.1->-r bipartiteSBM/requirements.txt (line 19)) (3.0.7)
# Requirement already satisfied: cycler>=0.10 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from matplotlib>=3.1.1->-r bipartiteSBM/requirements.txt (line 19)) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from matplotlib>=3.1.1->-r bipartiteSBM/requirements.txt (line 19)) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from matplotlib>=3.1.1->-r bipartiteSBM/requirements.txt (line 19)) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from matplotlib>=3.1.1->-r bipartiteSBM/requirements.txt (line 19)) (2.8.2)
# Requirement already satisfied: networkx in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from clusim>=0.3.1->-r bipartiteSBM/requirements.txt (line 28)) (2.6.3)
# Requirement already satisfied: mpmath in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from clusim>=0.3.1->-r bipartiteSBM/requirements.txt (line 28)) (1.2.1)
# Requirement already satisfied: python-igraph in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from clusim>=0.3.1->-r bipartiteSBM/requirements.txt (line 28)) (0.9.9)
# Requirement already satisfied: joblib>=0.11 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from scikit-learn>=0.20.3->-r bipartiteSBM/requirements.txt (line 31)) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from scikit-learn>=0.20.3->-r bipartiteSBM/requirements.txt (line 31)) (3.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jinja2>=2.1->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (2.1.1)
# Requirement already satisfied: Send2Trash in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (1.8.0)
# Requirement already satisfied: prometheus-client in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (0.13.1)
# Requirement already satisfied: websocket-client in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (1.3.2)
# Requirement already satisfied: anyio>=3.1.0 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (3.5.0)
# Requirement already satisfied: pyzmq>=17 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (22.3.0)
# Requirement already satisfied: argon2-cffi in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (21.3.0)
# Requirement already satisfied: nbformat>=5.2.0 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (5.2.0)
# Requirement already satisfied: traitlets>=5 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (5.1.1)
# Requirement already satisfied: jupyter-client>=6.1.1 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (7.2.0)
# Requirement already satisfied: nbconvert in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (6.4.5)
# Requirement already satisfied: terminado>=0.8.3 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (0.13.3)
# Requirement already satisfied: jsonschema>=3.0.1 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jupyterlab-server~=2.10->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (4.4.0)
# Requirement already satisfied: json5 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jupyterlab-server~=2.10->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (0.9.6)
# Requirement already satisfied: babel in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jupyterlab-server~=2.10->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (2.9.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jupyterlab-server~=2.10->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (0.4)
# Requirement already satisfied: requests in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jupyterlab-server~=2.10->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (2.27.1)
# Requirement already satisfied: notebook-shim>=0.1.0 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from nbclassic~=0.2->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (0.1.0)
# Requirement already satisfied: notebook<7 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from nbclassic~=0.2->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (6.4.10)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib>=3.1.1->-r bipartiteSBM/requirements.txt (line 19)) (1.15.0)
# Requirement already satisfied: pexpect>4.3 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from ipython->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (4.8.0)
# Requirement already satisfied: appnope in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from ipython->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (0.1.2)
# Requirement already satisfied: decorator in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from ipython->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (5.1.1)
# Requirement already satisfied: stack-data in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from ipython->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from ipython->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (0.1.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from ipython->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (3.0.28)
# Requirement already satisfied: pygments>=2.4.0 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from ipython->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (2.11.2)
# Requirement already satisfied: backcall in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from ipython->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from ipython->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (0.18.1)
# Requirement already satisfied: pickleshare in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from ipython->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (0.7.5)
# Requirement already satisfied: igraph==0.9.9 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from python-igraph->clusim>=0.3.1->-r bipartiteSBM/requirements.txt (line 28)) (0.9.9)
# Requirement already satisfied: texttable>=1.6.2 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from igraph==0.9.9->python-igraph->clusim>=0.3.1->-r bipartiteSBM/requirements.txt (line 28)) (1.6.4)
# Requirement already satisfied: sniffio>=1.1 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from anyio>=3.1.0->jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (1.2.0)
# Requirement already satisfied: idna>=2.8 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from anyio>=3.1.0->jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (3.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jedi>=0.16->ipython->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (0.8.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (5.6.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (0.18.1)
# Requirement already satisfied: nest-asyncio>=1.5.1 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from jupyter-client>=6.1.1->jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (1.5.4)
# Requirement already satisfied: ipykernel in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from notebook<7->nbclassic~=0.2->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (6.10.0)
# Requirement already satisfied: ipython-genutils in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from notebook<7->nbclassic~=0.2->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (0.2.0)
# Requirement already satisfied: defusedxml in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (0.7.1)
# Requirement already satisfied: testpath in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (0.6.0)
# Requirement already satisfied: bleach in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (4.1.0)
# Requirement already satisfied: jupyterlab-pygments in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (0.8.4)
# Requirement already satisfied: beautifulsoup4 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (4.10.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (1.5.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from pexpect>4.3->ipython->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (0.2.5)
# Requirement already satisfied: argon2-cffi-bindings in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from argon2-cffi->jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from babel->jupyterlab-server~=2.10->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (2021.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from requests->jupyterlab-server~=2.10->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from requests->jupyterlab-server~=2.10->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from requests->jupyterlab-server~=2.10->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (2.0.12)
# Requirement already satisfied: executing in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from stack-data->ipython->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (0.8.3)
# Requirement already satisfied: asttokens in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from stack-data->ipython->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from stack-data->ipython->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (0.2.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from importlib-resources>=1.4.0->jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (3.7.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from beautifulsoup4->nbconvert->jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (2.3.1)
# Requirement already satisfied: webencodings in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from bleach->nbconvert->jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (0.5.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from ipykernel->notebook<7->nbclassic~=0.2->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (1.6.0)
# Requirement already satisfied: psutil in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from ipykernel->notebook<7->nbclassic~=0.2->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (5.9.0)
# Requirement already satisfied: pycparser in /Users/Admin/Library/Python/3.8/lib/python/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.4->jupyterlab>=0.35.4->-r bipartiteSBM/requirements.txt (line 16)) (2.21)

# %%
import networkx as nx
import numpy as np
import matplotlib
import matplotlib.pylab as plt
import random
import copy
import pandas as pd

from biSBM.ioutils import get_types

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-6b892c6c9098> in <module>
#       7 import pandas as pd
#       8
# ----> 9 from biSBM.ioutils import get_types
#      10
#      11 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'biSBM'

# %%
def drawGz(G,z):
    # input  : a graph G and a partition dictionary z
    # output : prints a graph with colored nodes corresponding to groups
    
    colors = ['#d61111','#11c6d6','#d67711','#11d646','#1b11d6','#d611cc'] # map node labels to colors (for the visualization)
    node_colors = []
    for i in G.nodes():
        node_colors.append(colors[int(z[i])])
    nsize  = 600
    flabel = True
    if G.order() > 50:
        nsize  = 100
        flabel = False   
    nx.draw_networkx(G,with_labels=flabel,node_size=nsize,width=2,node_color=node_colors) # draw it pretty
    limits=plt.axis('off')                                      # turn off axes
    plt.show() 

    return

# %%
fname1 = 'sup3.txt'

dfHSDN = pd.read_csv(fname1, sep = '\t')
print(dfHSDN.head())
print(dfHSDN.tail())

# print(dfHSDN.columns)

Ghsdn = nx.from_pandas_edgelist(dfHSDN, 'MeSH Disease Term', 'MeSH Symptom Term', edge_key="TFIDF score",)

n = Ghsdn.number_of_nodes()
m = Ghsdn.number_of_edges()

print(f'number of nodes, n  = {n}')
print(f'number of edges, m  = {m}') # 4802 missing edges?
# Out:
#   MeSH Symptom Term                       MeSH Disease Term  \
# 0  Aging, Premature  Respiratory Syncytial Virus Infections
# 1  Aging, Premature             Orthomyxoviridae Infections
# 2  Aging, Premature                          HIV Infections
# 3  Aging, Premature      Acquired Immunodeficiency Syndrome
# 4  Aging, Premature                        Breast Neoplasms
#
#    PubMed occurrence  TFIDF score
# 0                  1     3.464551
# 1                  1     3.464551
# 2                  3    10.393654
# 3                  3    10.393654
# 4                  1     3.464551
#        MeSH Symptom Term     MeSH Disease Term  PubMed occurrence  TFIDF score
# 147973         Hirsutism  Tobacco Use Disorder                  1     2.483722
# 147974         Hirsutism      Radius Fractures                  1     2.483722
# 147975         Hirsutism                 Burns                  1     2.483722
# 147976         Hirsutism      Colles' Fracture                  1     2.483722
# 147977         Hirsutism    Radiation Injuries                  1     2.483722
# number of nodes, n  = 4293
# number of edges, m  = 143176

# %%
#with_labels = 'True'
# plt.figure(figsize = (12, 6)) # Define new figure size because default figure produced turned out to be too smal
# hsdnLayoutGraph = nx.draw_spring(Ghsdn, with_labels = 'True', node_size = 500, font_color = 'black', node_color = 'blue') # Use nx.draw_spring to draw graph in spring layout. Use white on blue color scheme
# plt.show() # Show the layout itself after graph has been built

uniqueDiseases = sum(dfHSDN["MeSH Symptom Term"].value_counts())
print(uniqueDiseases)

print()

uniqueSymptomLabels = dfHSDN["MeSH Symptom Term"].unique()
print(uniqueSymptomLabels)

print()

uniqueDiseaseLabels = dfHSDN["MeSH Disease Term"].unique()
print(uniqueDiseaseLabels)
print(len(uniqueDiseaseLabels))
# Out:
# 147978
#
# ['Aging, Premature' 'Asthenia' 'Fever' 'Fever of Unknown Origin'
#  'Sweating Sickness' 'Hypothermia' 'Body Weight' 'Birth Weight'
#  'Fetal Macrosomia' 'Body Weight Changes' 'Weight Gain' 'Weight Loss'
#  'Emaciation' 'Cachexia' 'Fetal Weight' 'Overweight' 'Obesity'
#  'Obesity, Morbid' 'Thinness' 'Cardiac Output, High' 'Cardiac Output, Low'
#  'Chills' 'Cyanosis' 'Infantile Apparent Life-Threatening Event' 'Edema'
#  'Edema, Cardiac' 'Hydrops Fetalis' 'Eye Manifestations' 'Eye Hemorrhage'
#  'Eye Pain' 'Susac Syndrome' 'Fatigue' 'Mental Fatigue' 'Feminization'
#  'Fetal Distress' 'Flushing' 'Heart Murmurs' 'Systolic Murmurs'
#  'Hot Flashes' 'Hypergammaglobulinemia' 'Intermittent Claudication'
#  'Mobility Limitation' 'Motion Sickness' 'Space Motion Sickness'
#  'Neurologic Manifestations' 'Cerebrospinal Fluid Otorrhea'
#  'Cerebrospinal Fluid Rhinorrhea' 'Decerebrate State' 'Dyskinesias'
#  'Ataxia' 'Cerebellar Ataxia' 'Gait Ataxia' 'Athetosis' 'Catalepsy'
#  'Chorea' 'Dystonia' 'Torticollis' 'Hyperkinesis' 'Hypokinesia'
#  'Myoclonus' 'Psychomotor Agitation' 'Akathisia, Drug-Induced'
#  'Synkinesis' 'Tics' 'Tremor' 'Gait Disorders, Neurologic' 'Gait Apraxia'
#  'Meningism' 'Neurobehavioral Manifestations' 'Apraxias'
#  'Alien Hand Syndrome' 'Catatonia' 'Communication Disorders'
#  'Language Disorders' 'Agraphia' 'Anomia' 'Dyslexia' 'Dyslexia, Acquired'
#  'Alexia, Pure' 'Language Development Disorders' 'Speech Disorders'
#  'Aphasia' 'Aphasia, Broca' 'Aphasia, Conduction'
#  'Aphasia, Primary Progressive' 'Primary Progressive Nonfluent Aphasia'
#  'Aphasia, Wernicke' 'Articulation Disorders' 'Dysarthria' 'Echolalia'
#  'Mutism' 'Stuttering' 'Learning Disorders' 'Confusion' 'Delirium'
#  'Consciousness Disorders' 'Unconsciousness' 'Coma'
#  'Persistent Vegetative State' 'Stupor' 'Syncope' 'Syncope, Vasovagal'
#  'Lethargy' 'Memory Disorders' 'Amnesia' 'Amnesia, Anterograde'
#  'Amnesia, Retrograde' 'Amnesia, Transient Global' 'Korsakoff Syndrome'
#  'Mental Retardation' 'Perceptual Disorders' 'Agnosia'
#  'Gerstmann Syndrome' 'Prosopagnosia' 'Auditory Perceptual Disorders'
#  'Hallucinations' 'Illusions' 'Phantom Limb' 'Psychomotor Disorders'
#  'Apraxia, Ideomotor' 'Fasciculation' 'Muscle Cramp' 'Muscle Hypertonia'
#  'Muscle Rigidity' 'Muscle Spasticity' 'Muscle Hypotonia'
#  'Muscle Weakness' 'Muscular Atrophy' 'Sarcopenia' 'Myokymia' 'Myotonia'
#  'Spasm' 'Hemifacial Spasm' 'Trismus' 'Tetany' 'Orthostatic Intolerance'
#  'Pain' 'Back Pain' 'Low Back Pain' 'Facial Pain' 'Headache'
#  'Slit Ventricle Syndrome' 'Labor Pain' 'Metatarsalgia' 'Neck Pain'
#  'Neuralgia' 'Neuralgia, Postherpetic' 'Piriformis Muscle Syndrome'
#  'Sciatica' 'Pain, Intractable' 'Pain, Referred' 'Paralysis'
#  'Facial Paralysis' 'Gastroparesis' 'Hemiplegia' 'Ophthalmoplegia'
#  'Ophthalmoplegia, Chronic Progressive External'
#  'Supranuclear Palsy, Progressive' 'Paraplegia' 'Brown-Sequard Syndrome'
#  'Pseudobulbar Palsy' 'Quadriplegia' 'Respiratory Paralysis'
#  'Vocal Cord Paralysis' 'Paresis' 'Paraparesis' 'Paraparesis, Spastic'
#  'Psychophysiologic Disorders' 'Pupil Disorders' 'Anisocoria' 'Miosis'
#  'Horner Syndrome' 'Tonic Pupil' 'Reflex, Abnormal' 'Reflex, Babinski'
#  'Seizures' 'Sensation Disorders' 'Dizziness' 'Hearing Disorders'
#  'Hearing Loss' 'Deafness' 'Deaf-Blind Disorders'
#  'Hearing Loss, Bilateral' 'Hearing Loss, Conductive'
#  'Hearing Loss, Functional' 'Hearing Loss, High-Frequency'
#  'Hearing Loss, Mixed Conductive-Sensorineural'
#  'Hearing Loss, Sensorineural' 'Hearing Loss, Central'
#  'Hearing Loss, Noise-Induced' 'Presbycusis' 'Usher Syndromes'
#  'Hearing Loss, Sudden' 'Hearing Loss, Unilateral' 'Hyperacusis'
#  'Tinnitus' 'Olfaction Disorders' 'Somatosensory Disorders' 'Hyperalgesia'
#  'Hyperesthesia' 'Hypesthesia' 'Paresthesia' 'Taste Disorders' 'Ageusia'
#  'Dysgeusia' 'Vision Disorders' 'Amblyopia' 'Blindness' 'Amaurosis Fugax'
#  'Blindness, Cortical' 'Color Vision Defects' 'Diplopia' 'Hemianopsia'
#  'Photophobia' 'Scotoma' 'Vision, Low' 'Sleep Disorders'
#  'Sleep Deprivation' 'Urinary Bladder, Neurogenic' 'Vertigo'
#  'Voice Disorders' 'Aphonia' 'Dysphonia' 'Hoarseness'
#  'Oral Manifestations' 'Oral Hemorrhage' 'Abdominal Pain' 'Abdomen, Acute'
#  'Colic' 'Renal Colic' 'Arthralgia' 'Shoulder Pain' 'Chest Pain'
#  'Angina Pectoris' 'Acute Coronary Syndrome' 'Angina, Unstable'
#  'Angina Pectoris, Variant' 'Earache' 'Toothache' 'Flank Pain'
#  'Glossalgia' 'Pain, Postoperative' 'Pelvic Pain' 'Dysmenorrhea'
#  'Pseudophakia' 'Reticulocytosis' 'Aerophagy' 'Anorexia' 'Constipation'
#  'Coprophagia' 'Diarrhea' 'Diarrhea, Infantile' 'Dyspepsia' 'Encopresis'
#  'Eructation' 'Flatulence' 'Gagging' 'Halitosis' 'Heartburn' 'Hiccup'
#  'Hyperphagia' 'Bulimia' 'Nausea' 'Postoperative Nausea and Vomiting'
#  'Vomiting' 'Hematemesis' 'Morning Sickness' 'Hyperemesis Gravidarum'
#  'Vomiting, Anticipatory' 'Anoxia' 'Fetal Hypoxia' 'Apnea'
#  'Cheyne-Stokes Respiration' 'Cough' 'Dyspnea' 'Dyspnea, Paroxysmal'
#  'Hemoptysis' 'Hypercapnia' 'Hyperoxia' 'Hyperventilation' 'Hypocapnia'
#  'Hypoventilation' 'Mouth Breathing' 'Respiratory Aspiration'
#  'Respiratory Sounds' 'Snoring' 'Sneezing' 'Skin Manifestations'
#  'Cafe-au-Lait Spots' 'Ecchymosis' 'Jaundice' 'Jaundice, Obstructive'
#  'Livedo Reticularis' 'Necrolytic Migratory Erythema' 'Pallor' 'Pruritus'
#  'Tinea Pedis' 'Purpura' 'Purpura Fulminans' 'Purpura, Hyperglobulinemic'
#  'Purpura, Schoenlein-Henoch' 'Purpura, Thrombocytopenic'
#  'Purpura, Thrombocytopenic, Idiopathic'
#  'Purpura, Thrombotic Thrombocytopenic' 'Waterhouse-Friderichsen Syndrome'
#  'Striae Distensae' 'Dysuria' 'Hypercalciuria' 'Nocturia' 'Oliguria'
#  'Polyuria' 'Prostatism' 'Proteinuria' 'Albuminuria' 'Hemoglobinuria'
#  'Urinary Bladder, Overactive' 'Urinary Incontinence'
#  'Urinary Incontinence, Stress' 'Urinary Incontinence, Urge' 'Urinoma'
#  'Virilism' 'Hirsutism']
#
# ['Respiratory Syncytial Virus Infections' 'Orthomyxoviridae Infections'
#  'HIV Infections' ... 'Antley-Bixler Syndrome Phenotype'
#  '46, XX Disorders of Sex Development'
#  '46, XY Disorders of Sex Development']
# 4219

# %%
nx.is_connected(Ghsdn)
print(nx.number_connected_components(Ghsdn))
print(nx.node_connected_component(Ghsdn, 'Aging, Premature'))
print([len(c) for c in sorted(nx.connected_components(Ghsdn), key=len, reverse=True)])
# Out:
# 2
# {'Peanut Hypersensitivity', 'Transsexualism', 'Jacobsen Distal 11q Deletion Syndrome', 'Flatfoot', 'Muscular Diseases', 'Ichthyosis, Lamellar', 'MPTP Poisoning', 'Biliary Tract Neoplasms', 'Siderosis', 'Muscular Dystrophy, Emery-Dreifuss', 'Exocrine Pancreatic Insufficiency', 'Sexually Transmitted Diseases', 'Leukoplakia', 'Brain Death', 'Premature Birth', 'Phobic Disorders', 'Chondrosarcoma, Mesenchymal', 'Tuberculosis, Bovine', 'Ectodermal Dysplasia', 'Joint Loose Bodies', 'Fibrosis', 'Histoplasmosis', 'Hypersensitivity, Immediate', 'Friedreich Ataxia', 'Failed Back Surgery Syndrome', 'Pregnancy, Ectopic', 'Optic Nerve Neoplasms', 'Periarthritis', 'Stereotypic Movement Disorder', 'Maxillofacial Abnormalities', 'Fetal Distress', 'Cystitis', 'Positive-Pressure Respiration, Intrinsic', 'Back Pain', 'Asthenopia', 'Rupture, Spontaneous', 'Abortion, Veterinary', 'Ureteral Obstruction', 'Leukemic Infiltration', 'Hypoproteinemia', 'Malocclusion, Angle Class II', 'Puberty, Precocious', 'Burns, Inhalation', 'Cystadenoma, Papillary', 'Mongolian Spot', 'Hand Dermatoses', 'Rigor Mortis', 'Gastrointestinal Diseases', 'Angioedema', 'Brucellosis', 'Achondroplasia', 'Folliculitis', 'Optic Nerve Glioma', 'Orofaciodigital Syndromes', 'Dystonia Musculorum Deformans', 'Carcinoma, Giant Cell', 'Dermatitis, Perioral', 'Gonadal Dysgenesis, 46,XY', 'Lateral Medullary Syndrome', 'Postoperative Complications', 'Creutzfeldt-Jakob Syndrome', 'Endocarditis', 'Pancreatic Pseudocyst', 'Dystonia', 'Urticaria Pigmentosa', 'Pituitary ACTH Hypersecretion', 'Serositis', 'Colitis, Collagenous', 'Tinea Favosa', 'Anuria', 'Ventricular Flutter', 'Equine Infectious Anemia', 'Post-Traumatic Headache', 'Pulmonary Emphysema', 'Hydropneumothorax', 'Brucellosis, Bovine', 'Pityriasis', 'Arthritis, Reactive', 'Macrophage Activation Syndrome', 'Tuberculosis, Avian', 'Puerperal Infection', 'Central Nervous System Fungal Infections', 'Mitral Valve Prolapse', 'Mycobacterium avium-intracellulare Infection', 'Sunstroke', 'Carcinoma, Transitional Cell', 'Granuloma, Giant Cell', 'Croup', 'Neurofibromatoses', 'Mobius Syndrome', 'Hypothyroidism', 'Scleroderma, Diffuse', 'Infertility, Female', 'Alcohol-Related Disorders', 'Developmental Disabilities', 'Soft Tissue Infections', 'Hypertrophy, Right Ventricular', 'Necatoriasis', 'Thrombocytopenia, Neonatal Alloimmune', 'Pasteurella Infections', 'Neoplasms, Gonadal Tissue', 'Dictyocaulus Infections', 'Tissue Adhesions', 'Eczema', 'Tricuspid Atresia', 'Zygomatic Fractures', 'Gastrointestinal Stromal Tumors', 'Rhabdomyolysis', 'Polyradiculoneuropathy, Chronic Inflammatory Demyelinating', 'Arrhythmia, Sinus', 'Parkinson Disease', 'Urinary Bladder Neck Obstruction', 'Tuberculosis, Laryngeal', 'Gastroparesis', 'Zellweger Syndrome', 'Chromosome Duplication', 'Folic Acid Deficiency', 'Cardiomegaly', 'Niemann-Pick Diseases', 'Arachnoiditis', 'Mucocele', 'Colonic Diseases', 'Choroiditis', 'Erythromelalgia', 'Nevus, Pigmented', 'Acne Vulgaris', 'Wrist Injuries', 'Histiocytosis, Sinus', 'Trichotillomania', 'Epidermolysis Bullosa Dystrophica', 'Encephalitis, Viral', 'Clostridium Infections', 'Solitary Fibrous Tumor, Pleural', 'Muscular Disorders, Atrophic', 'Diseases in Twins', 'Urinoma', 'Bronchial Diseases', 'Fatigue', 'Epidural Abscess', 'Mushroom Poisoning', 'Galactorrhea', 'Asbestosis', 'Citrullinemia', 'Cherubism', 'Maxillary Diseases', 'Astrocytoma', 'Upper Extremity Deformities, Congenital', 'Adrenal Rest Tumor', 'Dyspareunia', 'Motion Sickness', 'Retinal Vasculitis', 'Pyloric Stenosis', 'Pain, Intractable', 'Skin Diseases, Eczematous', 'Ventricular Fibrillation', 'Gas Gangrene', 'Ovarian Neoplasms', 'Choroid Diseases', 'Bundle-Branch Block', 'Dysarthria', 'Intraoperative Complications', 'Lymphangioleiomyomatosis', 'Plant Poisoning', 'Parasystole', 'Mesenteric Cyst', 'Melanoma, Experimental', 'Wolman Disease', 'Hypercalciuria', 'Tachycardia, Paroxysmal', 'Whooping Cough', 'Persistent Hyperplastic Primary Vitreous', 'Ventricular Outflow Obstr ...
# [4292, 1]

# %%
# Remove extraneous connected component

for component in list(nx.connected_components(Ghsdn)):
    if len(component)<3:
        for node in component:
            Ghsdn.remove_node(node)

# %%
# Plot CCDF from PS3
def plot_CCDF(kis):
    # input : a list of degrees, e.g., from a networkx graph G
    # output: a plot of the CCDF of the degree distribution Pr(K>=k) for k>=1
    
    kmax = max(kis)

    # histogram and plot
    counts, bins = np.histogram(kis, bins=[i for i in range(kmax+2)], density=True)
    cumcounts = np.cumsum(counts)
    cumcounts = np.insert(cumcounts,0,0)
    plt.loglog(bins[1:-1], 1-cumcounts[1:-1], 'rs', alpha=0.5)
    plt.xlabel('Degree, k')
    plt.ylabel('Pr(K>=k)')
    plt.show()
    return

# %%
# Calculate summary statistics. Network is disconnected it seems like so should we instead to edge prediction?

diameter = nx.diameter(Ghsdn)
ellmean = nx.average_shortest_path_length(Ghsdn)
C = nx.transitivity(Ghsdn) 
h = nx.number_connected_components(Ghsdn)
degrees = [i[1] for i in Ghsdn.degree()]
kmax = max(degrees)
kstd = np.std(degrees)

plot_CCDF(degrees) # Call plot_CCDF on degrees list

print(f'diameter = {diameter}')
print(f'mean geodesic distance, <ell> = %5.2f' % ellmean)
print(f'clustering coefficient, C     = %5.2f' % C)
print(f'number of components,   h     =  {h}')
print(f'max degree, k_max = {kmax}')
print(f'max degree, k_std = %5.2f' % kstd)
# Out:
# diameter = 4
# mean geodesic distance, <ell> =  2.16
# clustering coefficient, C     =  0.09
# number of components,   h     =  1
# max degree, k_max = 2660
# max degree, k_std = 175.35

# %%
# Bipartite DC-SBM, more recent Larremore paper on block models
